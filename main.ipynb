# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("predictions.csv")
df.drop(labels=["Unnamed: 0"], axis=1, inplace=True)
df.head()
# Out:
#                                           prediction          source  \
# 0            Buy Sun TV Network, target price Rs 750   Motilal Oswal
# 1             Buy Ashok Leyland, target price Rs 215   Motilal Oswal
# 2  Buy Apollo Hospitals Enterprise, target price ...   Motilal Oswal
# 3       Buy Hindalco Industries, target price Rs 580   Motilal Oswal
# 4                Buy Coal India, target price Rs 380   Motilal Oswal
#
#                                           stock_info  \
# 0  Sun TV Network Ltd., incorporated in the year ...
# 1  Ashok Leyland Ltd., incorporated in the year 1...
# 2  Apollo Hospitals Enterprise Ltd., incorporated...
# 3  Hindalco Industries Ltd. key Products/Revenue ...
# 4  Coal India Ltd., incorporated in the year 1973...
#
#                      datetime
# 0  Nov 13, 2023, 11:12 AM IST
# 1  Nov 13, 2023, 11:00 AM IST
# 2  Nov 13, 2023, 10:54 AM IST
# 3  Nov 13, 2023, 10:20 AM IST
# 4  Nov 13, 2023, 10:12 AM IST

# %%
d={'advice':[],'target':[],'stock':[]}
for ID,pred in df.iterrows():
    d["advice"].append(pred["prediction"].split()[0])
    d['target'].append(pred["prediction"].split()[-1])
    temp=pred["stock_info"].split(",")[0]
    d['stock'].append(temp.split(".")[0])

# %%
df["target"]=d["target"]
df["advice"]=d["advice"]
df["stock"]=d["stock"]

# %%
df["advice"].unique()
# Out:
# array(['Buy', 'Sell', 'Neutral', 'Accumulate', 'Reduce', 'Add'],
#       dtype=object)

# %%
df["advice"].replace(to_replace=['Accumulate','Reduce','Add'],value=['buy','sell','buy'],inplace=True)

# %%
df.head()
# Out:
#                                           prediction          source  \
# 0            Buy Sun TV Network, target price Rs 750   Motilal Oswal
# 1             Buy Ashok Leyland, target price Rs 215   Motilal Oswal
# 2  Buy Apollo Hospitals Enterprise, target price ...   Motilal Oswal
# 3       Buy Hindalco Industries, target price Rs 580   Motilal Oswal
# 4                Buy Coal India, target price Rs 380   Motilal Oswal
#
#                                           stock_info  \
# 0  Sun TV Network Ltd., incorporated in the year ...
# 1  Ashok Leyland Ltd., incorporated in the year 1...
# 2  Apollo Hospitals Enterprise Ltd., incorporated...
# 3  Hindalco Industries Ltd. key Products/Revenue ...
# 4  Coal India Ltd., incorporated in the year 1973...
#
#                      datetime target advice                            stock
# 0  Nov 13, 2023, 11:12 AM IST    750    Buy               Sun TV Network Ltd
# 1  Nov 13, 2023, 11:00 AM IST    215    Buy                Ashok Leyland Ltd
# 2  Nov 13, 2023, 10:54 AM IST   6070    Buy  Apollo Hospitals Enterprise Ltd
# 3  Nov 13, 2023, 10:20 AM IST    580    Buy          Hindalco Industries Ltd
# 4  Nov 13, 2023, 10:12 AM IST    380    Buy                   Coal India Ltd

# %%
df["stock"].value_counts()
# Out:
# stock
# Tata Motors Ltd            4
# ICICI Bank Ltd             4
# Maruti Suzuki India Ltd    3
# HDFC Bank Ltd              3
# State Bank of India        3
#                           ..
# Canara Bank                1
# Indian Bank                1
# KNR Constructions Ltd      1
# Rallis India Ltd           1
# Zen Technologies Ltd       1
# Name: count, Length: 139, dtype: int64

# %%
# df=df[df.duplicated(subset="stock", keep=False)]

# %%
# Find the counts of each stock
stock_counts = df['stock'].value_counts()

# Get the stocks with counts greater than 3
stocks_with_more_than_3_occurrences = stock_counts[stock_counts > 2].index

# Filter the DataFrame based on the condition
filtered_df = df[df['stock'].isin(stocks_with_more_than_3_occurrences)]

filtered_df
# Out:
#                                          prediction                   source  \
# 1            Buy Ashok Leyland, target price Rs 215            Motilal Oswal
# 6     Buy Mahindra & Mahindra, target price Rs 1775            Motilal Oswal
# 16             Buy Tata Motors, target price Rs 750            Motilal Oswal
# 43    Buy Reliance Industries, target price Rs 2760            Motilal Oswal
# 44   Buy Maruti Suzuki India, target price Rs 12300            Motilal Oswal
# 58              Buy Axis Bank, target price Rs 1150            Motilal Oswal
# 59             Buy ICICI Bank, target price Rs 1230              BNP Paribas
# 70             Buy ICICI Bank, target price Rs 1120            Motilal Oswal
# 100             Buy HDFC Bank, target price Rs 2025      Prabhudas Lilladher
# 103    Buy State Bank of India, target price Rs 790          HDFC Securities
# 123    Buy State Bank of India, target price Rs 770      Prabhudas Lilladher
# 125   Buy Reliance Industries, target price Rs 2913      Prabhudas Lilladher
# 130            Buy Tata Motors, target price Rs 760      Prabhudas Lilladher
# 131  Buy Maruti Suzuki India, target price Rs 11500      Prabhudas Lilladher
# 132   Buy Mahindra & Mahindra, target price Rs 1775      Prabhudas Lilladher
# 134          Buy Ashok Leyland, target price Rs 220      Prabhudas Lilladher
# 139   Buy Reliance Industries, target price Rs 2900             JM Financial
# 144             Buy Axis Bank, target price Rs 1040             JM Financial
# 145            Buy ICICI Bank, target price Rs 1115             JM Financial
# 146             Buy HDFC Bank, target price Rs 1850             JM Financial
# 149            Buy Tata Motors, target price Rs 740            Motilal Oswal
# 157    Buy State Bank of India, target price Rs 790   BNP Paribas Securities
# 158             Buy Axis Bank, target price Rs 1290   BNP Paribas Securities
# 159            Buy ICICI Bank, target price Rs 1230   BNP Paribas Securities
# 160             Buy HDFC Bank, target price Rs 2210   BNP Paribas Securities
# 165          Buy Ashok Leyland, target price Rs 210            Motilal Oswal
# 166            Buy Tata Motors, target price Rs 750            Motilal Oswal
# 167   Buy Mahindra & Mahindra, target price Rs 1725            Motilal Oswal
# 168  Buy Maruti Suzuki India, target price Rs 11150            Motilal Oswal
#
#                                             stock_info  \
# 1    Ashok Leyland Ltd., incorporated in the year 1...
# 6    Mahindra & Mahindra Ltd., incorporated in the ...
# 16   Tata Motors Ltd., incorporated in the year 194...
# 43   Reliance Industries Ltd. key Products/Revenue ...
# 44   Maruti Suzuki India Ltd., incorporated in the ...
# 58   Axis Bank Ltd., incorporated in the year 1993,...
# 59   ICICI Bank Ltd., incorporated in the year 1994...
# 70   ICICI Bank Ltd., incorporated in the year 1994...
# 100  HDFC Bank Ltd., incorporated in the year 1994,...
# 103  State Bank of India, incorporated in the year ...
# 123  State Bank of India, incorporated in the year ...
# 125  Reliance Industries Ltd., incorporated in the ...
# 130  Tata Motors Ltd., incorporated in the year 194...
# 131  Maruti Suzuki India Ltd. key Products/Revenue ...
# 132  Mahindra & Mahindra Ltd. key Products/Revenue ...
# 134  Ashok Leyland Ltd. key Products/Revenue Segmen...
# 139  Reliance Industries Ltd. key Products/Revenue ...
# 144  Axis Bank Ltd., incorporated in the year 1993,...
# 145  ICICI Bank Ltd., incorporated in the year 1994...
# 146  HDFC Bank Ltd., incorporated in the year 1994,...
# 149  Tata Motors Ltd. key Products/Revenue Segments...
# 157  State Bank of India, incorporated in the year ...
# 158  Axis Bank Ltd., incorporated in the year 1993,...
# 159  ICICI Bank Ltd., incorporated in the year 1994...
# 160  HDFC Bank Ltd., incorporated in the year 1994,...
# 165  Ashok Leyland Ltd., incorporated in the year 1...
# 166  Tata Motors Ltd., incorporated in the year 194...
# 167  Mahindra & Mahindra Ltd., incorporated in the ...
# 168  Maruti Suzuki India Ltd., incorporated in the ...
#
#                        datetime target advice                    stock
# 1    Nov 13, 2023, 11:00 AM IST    215    Buy        Ashok Leyland Ltd
# 6    Nov 13, 2023, 09:23 AM IST   1775    Buy  Mahindra & Mahindra Ltd
# 16    Nov 3, 2023, 11:51 AM IST    750    Buy          Tata Motors Ltd
# 43   Oct 30, 2023, 09:35 AM IST   2760    Buy  Reliance Industries Ltd
# 44   Oct 30, 2023, 09:30 AM IST  12300    Buy  Maruti Suzuki India Ltd
# 58   Oct 26, 2023, 09:18 AM IST   1150    Buy            Axis Bank Ltd
# 59   Oct 25, 2023, 10:38 AM IST   1230    Buy           ICICI Bank Ltd
# 70   Oct 23, 2023, 10:43 AM IST   1120    Buy           ICICI Bank Ltd
# 100  Oct 17, 2023, 09:34 AM IST   2025    Buy            HDFC Bank Ltd
# 103  Oct 16, 2023, 10:36 AM IST    790    Buy      State Bank of India
# 123  Oct 11, 2023, 10:17 AM IST    770    Buy      State Bank of India
# 125  Oct 11, 2023, 10:09 AM IST   2913    Buy  Reliance Industries Ltd
# 130  Oct 10, 2023, 10:17 AM IST    760    Buy          Tata Motors Ltd
# 131  Oct 10, 2023, 10:13 AM IST  11500    Buy  Maruti Suzuki India Ltd
# 132  Oct 10, 2023, 09:35 AM IST   1775    Buy  Mahindra & Mahindra Ltd
# 134  Oct 10, 2023, 09:27 AM IST    220    Buy        Ashok Leyland Ltd
# 139   Oct 9, 2023, 10:31 AM IST   2900    Buy  Reliance Industries Ltd
# 144   Oct 6, 2023, 10:35 AM IST   1040    Buy            Axis Bank Ltd
# 145   Oct 6, 2023, 10:29 AM IST   1115    Buy           ICICI Bank Ltd
# 146   Oct 6, 2023, 10:21 AM IST   1850    Buy            HDFC Bank Ltd
# 149   Oct 6, 2023, 09:27 AM IST    740    Buy          Tata Motors Ltd
# 157   Oct 4, 2023, 10:55 AM IST    790    Buy      State Bank of India
# 158   Oct 4, 2023, 10:52 AM IST   1290    Buy            Axis Bank Ltd
# 159   Oct 4, 2023, 10:48 AM IST   1230    Buy           ICICI Bank Ltd
# 160   Oct 4, 2023, 10:41 AM IST   2210    Buy            HDFC Bank Ltd
# 165   Oct 3, 2023, 10:32 AM IST    210    Buy        Ashok Leyland Ltd
# 166   Oct 3, 2023, 10:23 AM IST    750    Buy          Tata Motors Ltd
# 167   Oct 3, 2023, 10:19 AM IST   1725    Buy  Mahindra & Mahindra Ltd
# 168   Oct 3, 2023, 10:09 AM IST  11150    Buy  Maruti Suzuki India Ltd

# %%
filtered_df.to_csv("refined_predictions.csv",index=False)

# %% [markdown]
# ### Fetching Real World Data from Yahoo Finance through API

# %%
import yfinance as yahooFinance
 
Tata_Motors = yahooFinance.Ticker("TATAMOTORS.NS")
Ashok_Leyland = yahooFinance.Ticker("ASHOKLEY.NS")
Mahindra = yahooFinance.Ticker("M&M.NS")
Reliance = yahooFinance.Ticker("RELIANCE.NS")
Maruti = yahooFinance.Ticker("MARUTI.NS")
hdfc = yahooFinance.Ticker("HDFCBANK.NS")
icici = yahooFinance.Ticker("ICICIBANK.NS")
axis = yahooFinance.Ticker("AXISBANK.NS")
sbi = yahooFinance.Ticker("SBIN.NS")


# Let us  get historical stock prices for Facebook 
# covering the past few years.
# max->maximum number of daily prices available 
# for Facebook.
# Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 
# 5y, 10y and ytd.

import pandas as pd

df=pd.DataFrame(Maruti.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Maruti Suzuki India Ltd.csv")
df=pd.DataFrame(sbi.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/State Bank of India.csv")
df=pd.DataFrame(axis.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Axis Bank Ltd.csv")
df=pd.DataFrame(icici.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/ICICI Bank Ltd.csv")
df=pd.DataFrame(Reliance.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Reliance Industries Ltd.csv")
df=pd.DataFrame(Mahindra.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Mahindra & Mahindra Ltd.csv")
df=pd.DataFrame(Ashok_Leyland.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Ashok Leyland Ltd.csv")
df=pd.DataFrame(Tata_Motors.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/Tata Motors Ltd.csv")
df=pd.DataFrame(hdfc.history(period="3y"))
df.index=df.index.date
df.to_csv("stock_dataset/HDFC Bank Ltd.csv")

# %% [markdown]
# ### Convert Stock Data To JSON format

# %%
import json
import os
import pandas as pd

files=os.listdir("stock_dataset")
# print(files)

data=[]
counter=1

for stock in files:
    d={"data":[]}
    df=pd.read_csv(f"stock_dataset/{stock}")
    name=stock.split(".")[0]
    d["name"]=name
    d["id"]=counter
    for ID,VALUE in df.iterrows():
        d['data'].append({"date":VALUE["Unnamed: 0"],"value":VALUE.Close})
    counter+=1
    data.append(d)
        
stocks_data=json.dumps(data,indent=2)

with open("Market_Stocks_Data", "w") as json_file:
    json_file.write(stocks_data)

print(f"JSON data has been saved to Market_Stocks_Data")
# Out:
# JSON data has been saved to Market_Stocks_Data

# %% [markdown]
# ### Calculating Credibility Scores

# %%
import pandas as pd

preds=pd.read_csv("refined_predictions.csv")
# preds.head()

preds.source.value_counts()
# Out:
# source
#  Motilal Oswal             12
#  Prabhudas Lilladher        7
#  JM Financial               4
#  BNP Paribas Securities     4
#  BNP Paribas                1
#  HDFC Securities            1
# Name: count, dtype: int64

# %%
def CRED_SCORE(preds2):    

    from datetime import date, timedelta
    from sklearn.metrics import mean_absolute_percentage_error

    PREDICTIONS=[]
    ACTUAL=[]
    predictions=[]
    for ID, DATA in preds2.iterrows():

        if (date.today() - DATA['datetime']) > timedelta(days=30):
            name=DATA.source

            df = pd.read_csv(f"stock_dataset/{DATA['stock']}.csv")
            df.index = pd.to_datetime(df["Unnamed: 0"])
            df.index=df.index.date

            start_date = DATA['datetime']
            end_date = start_date + timedelta(days=30)

            df = df[(df.index >= start_date) & (df.index <= end_date)]

            if DATA['advice'] == "Buy":
                change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
                PREDICTIONS.append(change)
                ACTUAL.append(DATA.target)
            else:
                change = float(-min(df['Close'])+df[df.index==DATA.datetime]['Close'])
                PREDICTIONS.append(change)
                ACTUAL.append(DATA.target)

        if  (date.today() - DATA['datetime']) < timedelta(days=60):
            d2={ "stockInfo": DATA.stock_info,
            "date": DATA.datetime.strftime('%Y-%m-%d'),
            "targetValue": DATA.target,
            "advice": DATA.advice}
            predictions.append(d2)
            
    credibility=abs(mean_absolute_percentage_error(ACTUAL,PREDICTIONS))*100

    return {"score":credibility,"predictions":predictions}

# %%
counter=0
json_file=[]

for person in preds["source"].unique():
    
    d={}

    preds2=preds[preds["source"]==person]
    preds2.datetime=pd.to_datetime(preds2.datetime)
    preds2.datetime=preds2.datetime.dt.date
    
    d["id"]= counter
    d["name"]= preds2.iloc[0].source
    d["description"]="ma_chuda"
    d["imageURL"]="naughty"

    d2=CRED_SCORE(preds2)
    d["credibilityScore"]=d2["score"]
    d["predictions"]=d2["predictions"]

    json_file.append(d)

    counter+=1

# print(json_file)

json_file=json.dumps(json_file,indent=2)

with open("Market_Predictions", "w") as js_file:
    js_file.write(json_file)

print(f"JSON data has been saved to Market_Predictions")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Nov 13, 2023, 11:00 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Oct 25, 2023, 10:38 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Oct 17, 2023, 09:34 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Oct 16, 2023, 10:36 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Oct 9, 2023, 10:31 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: FutureWarning: Parsed string "Oct 4, 2023, 10:55 AM IST" included an un-recognized timezone "IST". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=pd.to_datetime(preds2.datetime)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3714525355.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds2.datetime=preds2.datetime.dt.date
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26964\3924988845.py:24: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   change = float(max(df['Close'])-df[df.index==DATA.datetime]['Close'])
# [{'id': 0, 'name': ' Motilal Oswal', 'description': 'ma_chuda', 'imageURL': 'naughty', 'credibilityScore': 96.50848805107472, 'predictions': [{'stockInfo': 'Ashok Leyland Ltd., incorporated in the year 1948, is a Large Cap company (having a market cap of Rs 50897.77 Crore) operating in Auto sector.', 'date': '2023-11-13', 'targetValue': 215, 'advice': 'Buy'}, {'stockInfo': 'Mahindra & Mahindra Ltd., incorporated in the year 1945, is a Large Cap company (having a market cap of Rs 189793.59 Crore) operating in Auto sector.', 'date': '2023-11-13', 'targetValue': 1775, 'advice': 'Buy'}, {'stockInfo': 'Tata Motors Ltd., incorporated in the year 1945, is a Large Cap company (having a market cap of Rs 216963.91 Crore) operating in Auto sector.', 'date': '2023-11-03', 'targetValue': 750, 'advice': 'Buy'}, {'stockInfo': 'Reliance Industries Ltd. key Products/Revenue Segments include Petrochemicals, Oil & Gas, Income From Financial Services, Other Services, Others and Income from Retailing for the year ending 31-Mar-2022.', 'date': '2023-10-30', 'targetValue': 2760, 'advice': 'Buy'}, {'stockInfo': 'Maruti Suzuki India Ltd., incorporated in the year 1981, is a Large Cap company (having a market cap of Rs 319017.69 Crore) operating in Auto sector.', 'date': '2023-10-30', 'targetValue': 12300, 'advice': 'Buy'}, {'stockInfo': 'Axis Bank Ltd., incorporated in the year 1993, is a banking company (having a market cap of Rs 294446.84 Crore).', 'date': '2023-10-26', 'targetValue': 1150, 'advice': 'Buy'}, {'stockInfo': 'ICICI Bank Ltd., incorporated in the year 1994, is a banking company (having a market cap of Rs 653213.01 Crore).', 'date': '2023-10-23', 'targetValue': 1120, 'advice': 'Buy'}, {'stockInfo': 'Tata Motors Ltd. key Products/Revenue Segments include Motor Vehicles, Spare Parts & Others, Miscellaneous Goods, Sale of services and Other Operating Revenue for the year ending 31-Mar-2023.', 'date': '2023-10-06', 'targetValue': 740, 'advice': 'Buy'}, {'stockInfo': 'Ashok Leyland Ltd., incorporated in the year 1948, is a Large Cap company (having a market cap of Rs 52439.23 Crore) operating in Auto sector.', 'date': '2023-10-03', 'targetValue': 210, 'advice': 'Buy'}, {'stockInfo': 'Tata Motors Ltd., incorporated in the year 1945, is a Large Cap company (having a market cap of Rs 205982.24 Crore) operating in Auto sector.', 'date': '2023-10-03', 'targetValue': 750, 'advice': 'Buy'}, {'stockInfo': 'Mahindra & Mahindra Ltd., incorporated in the year 1945, is a Large Cap company (having a market cap of Rs 193188.42 Crore) operating in Auto sector.', 'date': '2023-10-03', 'targetValue': 1725, 'advice': 'Buy'}, {'stockInfo': 'Maruti Suzuki India Ltd., incorporated in the year 1981, is a Large Cap company (having a market cap of Rs 313861.18 Crore) operating in Auto sector.', 'date': '2023-10-03', 'targetValue': 11150, 'advice': 'Buy'}]}, {'id': 1, 'name': ' BNP Paribas', 'description': 'ma_chuda', 'imageURL': 'naughty', 'credibilityScore': 97.39837398373984, 'predictions': [{'stockInfo': 'ICICI Bank Ltd., incorporated in the year 1994, is a banking company (having a market cap of Rs 650271.72 Crore).', 'date': '2023-10-25', 'targetValue': 1230, 'advice': 'Buy'}]}, {'id': 2, 'name': ' Prabhudas Lilladher', 'description': 'ma_chuda', 'imageURL': 'naughty', 'credibilityScore': 98.19772724440695, 'predictions': [{'stockInfo': 'HDFC Bank Ltd., incorporated in the year 1994, is a banking company (having a market cap of Rs 1159714.58 Crore).', 'date': '2023-10-17', 'targetValue': 2025, 'advice': 'Buy'}, {'stockInfo': 'State Bank of India, incorporated in the year 1955, is a banking company (having a market cap of Rs 531549.89 Crore).', 'date': '2023-10-11', 'targetValue': 770, 'advice': 'Buy'}, {'stockInfo': 'Reliance Industries Ltd., incorporated in the year 1973, is a Large Cap company (having a market cap of Rs 1570447.73 Crore) operating in Diversified sector.', 'date': '2023-10-11', 'targetValue': 2913, 'advice': 'Buy'}, {'stockInfo': 'Tata Motors  ...
# JSON data has been saved to Market_Predictions
